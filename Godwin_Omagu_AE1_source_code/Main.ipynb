# %%
import csv
import process
import tui

tui.welcome()
    
def run():
    try:
        while True:
            menu_opt = tui.menu()
            if menu_opt == "a":
                print(process.a())
            elif menu_opt == "b":
                print(process.b())
            elif menu_opt == "c":
                print(process.c())
            elif menu_opt == "d":
                 print(process.d())
            elif menu_opt == "e":
                 print(process.e())
            elif menu_opt == "f":
                 print(process.f())
            elif menu_opt == "g":
                 print(process.g())
            elif menu_opt == "h":
                 print(process.h())
            elif menu_opt == "i":
                 print(process.i())
            elif menu_opt == "j":
                 print(process.j())
            elif menu_opt == "k":
                 print(process.k())
            elif menu_opt == "l":
                 print(process.l())
            elif menu_opt == "exit":
                print("End of session")
                print(tui.completion())
                break
            else:
                tui.error("Invalid Selection!") 
    except IOError:
            print("menu block not responding")      
if __name__ == "__main__":
    run()
# Out:
# What is your name? Godwin
# Hello Godwin, welcome to USA car market analysis program
# ****************************************************************************************************
# Car Price Analysis Program started:
#
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
#
# Your selection: a
#
# Query initiated: Loading records....
#
# 205 records loaded successfully
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
#
# Your selection: b
#
# Query initiated: Retrieving record for individual cars....
#
# What car ID information do you want (1-205)?
# 45
# car_ID                      45
# CarName           isuzu D-Max
# fueltype                   gas
# doornumber                   2
# carbody                  sedan
# drivewheel                 fwd
# enginelocation           front
# wheelbase                 94.5
# carlength                155.9
# carwidth                  63.6
# carheight                 52.0
# curbweight                1874
# enginetype                 ohc
# cylindernumber               4
# enginesize                  90
# fuelsystem                2bbl
# horsepower                  70
# citympg                     38
# highwaympg                  43
# price                     8916
# Name: 44, dtype: object
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
#
# Your selection: c
#
# Query initiated: Retrieving all cars for a specified cylinder number....
#
# Please select choice of car based on number of cylinder numbers(2,3,4,5,6,8,12)
# 5
#      car_ID                   CarName fueltype  doornumber    carbody  \
# 5         6                  audi fox      gas           2      sedan
# 6         7                audi 100ls      gas           4      sedan
# 7         8                 audi 5000      gas           4      wagon
# 8         9                 audi 4000      gas           4      sedan
# 9        10       audi 5000s (diesel)      gas           2  hatchback
# 67       68  buick electra 225 custom   diesel           4      sedan
# 68       69  buick century luxus (sw)   diesel           4      wagon
# 69       70             buick century   diesel           2    hardtop
# 70       71             buick skyhawk   diesel           4      sedan
# 191     192         volkswagen rabbit      gas           4      sedan
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 5          fwd          front       99.8      177.3      66.3       53.1
# 6          fwd          front      105.8      192.7      71.4       55.7
# 7          fwd          front      105.8      192.7      71.4       55.7
# 8          fwd          front      105.8      192.7      71.4       55.9
# 9          4wd          front       99.5      178.2      67.9       52.0
# 67         rwd          front      110.0      190.9      70.3       56.5
# 68         rwd          front      110.0      190.9      70.3       58.7
# 69         rwd          front      106.7      187.5      70.3       54.9
# 70         rwd          front      115.6      202.6      71.7       56.3
# 191        fwd          front      100.4      180.2      66.9       55.1
#
#      curbweight enginetype  cylindernumber  enginesize fuelsystem  horsepower  \
# 5          2507        ohc               5         136       mpfi         110
# 6          2844        ohc               5         136       mpfi         110
# 7          2954        ohc               5         136       mpfi         110
# 8          3086        ohc               5         131       mpfi         140
# 9          3053        ohc               5         131       mpfi         160
# 67         3515        ohc               5         183        idi         123
# 68         3750        ohc               5         183        idi         123
# 69         3495        ohc               5         183        idi         123
# 70         3770        ohc               5         183        idi         123
# 191        2661        ohc               5         136       mpfi         110
#
#      citympg  highwaympg  price
# 5         19          25  15250
# 6         19          25  17710
# 7         19          25  18920
# 8         17          20  23875
# 9         16          22  17859
# 67        22          25  25552
# 68        22          25  28248
# 69        22          25  28176
# 70        22          25  31600
# 191       19          24  13295
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
#
# Your selection: g
#                  car_ID                          CarName fueltype  doornumber  \
# carbody
# convertible 128     129                   porsche boxter      gas           2
#             72       73                    buick skylark      gas           2
#             172     173                  toyota cressida      gas           2
#             1         2              alfa-romero stelvio      gas           2
#             0         1               alfa-romero giulia      gas           2
# hardtop     74       75  buick regal sport coupe (turbo)      gas           2
#             127     128                  porsche cayenne      gas           2
#             126     127                porcshce panamera      gas           2
#             69       70                    buick century   diesel           2
#             170     171                    toyota tercel      gas           2
# hatchback   129     130                  porsche cayenne      gas           2
#             125     126                    porsche macan      gas           2
#             105     106                     nissan kicks      gas           2
#             106     107                   nissan clipper      gas           2
#             136     137                       saab 99gle      gas           2
# sedan       16       17                           bmw x5      gas           2
#             73       74            buick century special      gas           4
#             17       18                           bmw x3      gas           4
#             49       50                        jaguar xk      gas           2
#             48       49                        jaguar xf      gas           4
# wagon       68       69         buick century luxus (sw)   diesel           4
#             199     200                     volvo diesel      gas           4
#             7         8                        audi 5000      gas           4
#             114     115        peugeot 505s turbo diesel   diesel           4
#             113     114                      peugeot 504      gas           4
#
#                      carbody drivewheel enginelocation  wheelbase  carlength  \
# carbody
# convertible 128  convertible        rwd           rear       89.5      168.9
#             72   convertible        rwd          front       96.6      180.3
#             172  convertible        rwd          front       98.4      176.2
#             1    convertible        rwd          front       88.6      168.8
#             0    convertible        rwd          front       88.6      168.8
# hardtop     74       hardtop        rwd          front      112.0      199.2
#             127      hardtop        rwd           rear       89.5      168.9
#             126      hardtop        rwd           rear       89.5      168.9
#             69       hardtop        rwd          front      106.7      187.5
#             170      hardtop        rwd          front       98.4      176.2
# hatchback   129    hatchback        rwd          front       98.4      175.7
#             125    hatchback        rwd          front       94.5      168.9
#             105    hatchback        rwd          front       91.3      170.7
#             106    hatchback        rwd          front       99.2      178.5
#             136    hatchback        fwd          front       99.1      186.6
# sedan       16         sedan        rwd          front      103.5      193.8
#             73         sedan        rwd          front      120.9      208.1
#             17         sedan        rwd          front      110.0      197.0
#             49         sedan        rwd          front      102.0      191.7
#             48         sedan        rwd          front      113.0      199.6
# wagon       68         wagon        rwd          front      110.0      190.9
#             199        wagon        rwd          front      104.3      188.8
#             7          wagon        fwd          front      105.8      192.7
#             114        wagon        rwd          front      114.2      198.9
#             113        wagon        rwd          front      114.2      198.9
#
#                  carwidth  carheight  curbweight enginetype  cylindernumber  \
# carbody
# convertible 128      65.0       51.6        2800       ohcf               6
#             72       70.5       50.8        3685       ohcv               8
#             172      65.6       53.0        2975        ohc               4
#             1        64.1       48.8        2548       dohc               4
#             0        64.1       48.8        2548       dohc               4
# hardtop     74       72.0       55.4        3715       ohcv               8
#             127      65.0       51.6        2756       ohcf               6
#             126      65.0       51.6        2756       ohcf               6
#             69       70.3       54.9        3495        ohc               5
#             170      65.6       52.0        2679        ohc               4
# hatchback   129      72.3       50.5        3366      dohcv               8
#             125      68.3       50.2        2778        ohc               4
#             105      67.9       49.7        3139       ohcv               6
#             106      67.9       49.7        3139       ohcv               6
#             136      66.5       56.1        2808       dohc               4
# sedan       16       67.9       53.7        3380        ohc               6
#             73       71.7       56.7        3900       ohcv               8
#             17       70.9       56.3        3505        ohc               6
#             49       70.6       47.8        3950       ohcv              12
#             48       69.6       52.8        4066       dohc               6
# wagon       68       70.3       58.7        3750        ohc               5
#             199      67.2       57.5        3157        ohc               4
#             7        71.4       55.7        2954        ohc               5
#             114      68.4       58.7        3485          l               4
#             113      68.4       56.7        3285          l               4
#
#                  enginesize fuelsystem  horsepower  citympg  highwaympg  price
# carbody
# convertible 128         194       mpfi         207       17          25  37028
#             72          234       mpfi         155       16          18  35056
#             172         146       mpfi         116       24          30  17669
#             1           130       mpfi         111       21          27  16500
#             0           130       mpfi         111       21          27  13495
# hardtop     74          304       mpfi         184       14          16  45400
#             127         194       mpfi         207       17          25  34028
#             126         194       mpfi         207       17          25  32528
#             69          183        idi         123       22          25  28176
#             170         146       mpfi         116       24          30  11199
# hatchback   129         203       mpfi         288       17          28  31400
#             125         151       mpfi         143       19          27  22018
#             105         181       mpfi         200       17          23  19699
#             106         181       mpfi         160       19          25  18399
#             136         121       mpfi         160       19          26  18150
# sedan       16          209       mpfi         182       16          22  41315
#             73          308       mpfi         184       14          16  40960
#             17          209       mpfi         182       15          20  36880
#             49          326       mpfi         262       13          17  36000
#             48          258       mpfi         176       15          19  35550
# wagon       68          183        idi         123       22          25  28248
#             199         130       mpfi         162       17          22  18950
#             7           136       mpfi         110       19          25  18920
#             114         152        idi          95       25          25  17075
#             113         120       mpfi          95       19          24  16695
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
# Your selection: i
#
# Query initiated: Retrieving details of cars based on drivewheel....
#
#      car_ID                   CarName fueltype  doornumber    carbody  \
# 4         5                audi 100ls      gas           4      sedan
# 9        10       audi 5000s (diesel)      gas           2  hatchback
# 140     141                 subaru dl      gas           2  hatchback
# 144     145                 subaru r1      gas           4      sedan
# 145     146                 subaru r2      gas           4      sedan
# 148     149                 subaru dl      gas           4      wagon
# 149     150                 subaru dl      gas           4      wagon
# 154     155  toyota corolla 1600 (sw)      gas           4      wagon
# 155     156             toyota carina      gas           4      wagon
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 4          4wd          front       99.4      176.6      66.4       54.3
# 9          4wd          front       99.5      178.2      67.9       52.0
# 140        4wd          front       93.3      157.3      63.8       55.7
# 144        4wd          front       97.0      172.0      65.4       54.3
# 145        4wd          front       97.0      172.0      65.4       54.3
# 148        4wd          front       96.9      173.6      65.4       54.9
# 149        4wd          front       96.9      173.6      65.4       54.9
# 154        4wd          front       95.7      169.7      63.6       59.1
# 155        4wd          front       95.7      169.7      63.6       59.1
#
#      curbweight enginetype  cylindernumber  enginesize fuelsystem  horsepower  \
# 4          2824        ohc               3         136       mpfi         115
# 9          3053        ohc               5         131       mpfi         160
# 140        2240       ohcf               4         108       2bbl          73
# 144        2385       ohcf               4         108       2bbl          82
# 145        2510       ohcf               4         108       mpfi         111
# 148        2420       ohcf               4         108       2bbl          82
# 149        2650       ohcf               4         108       mpfi         111
# 154        2290        ohc               4          92       2bbl          62
# 155        3110        ohc               4          92       2bbl          62
#
#      citympg  highwaympg  price
# 4         18          22  17450
# 9         16          22  17859
# 140       26          31   7603
# 144       24          25   9233
# 145       24          29  11259
# 148       23          29   8013
# 149       23          23  11694
# 154       27          32   7898
# 155       27          32   8778
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
#
# Your selection: l
#
# Query initiated: Displaying percentage of car purchase in relation to horsepower....
# Query completed.
#
# None
# Please select from the following options:
#     [a] Load data
#     [b] Retrieve a record for an individual car by id
#     [c] Retrieve all cars for a specified cylinder number
#     [D] Retrieve all cars in the specified car body
#     [e] Retrieve a specific number of columns (2 up to 5) related to an individual car by id
#     [f] Retrieve the car names alphabetically
#     [g] Retrieve summary of sales (total car price) for each car body
#     [h] Retrieve the top 5 car sale by price (the most expensive) and per car body
#     [i] Retrieve the detail of cars based on your own selection
#     [j] Display the number of cars per fuel system using a bar chart
#     [k] Display the horsepower of the top 5 car sale by price (the cheapest) using a subplot
#     [l] Display the selection of data by your choice to present the customers’ buying behaviour using a suitable visualisation
#     [exit] Exit Program
